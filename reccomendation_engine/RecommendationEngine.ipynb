# %% [markdown]
# # code to generate data

# %%
import random
import pandas as pd
import numpy as np

# Define age range for non-mentor candidates
min_age = 17
max_age = 50

# Mean and standard deviation for ages of mentor candidates
mentor_mean_age = 30
mentor_std_dev = 5  # Adjust as needed

# Define possible locations
locations = [
    "Buffalo, NY",
    "Amherst, NY",
    "Cheektowaga, NY",
    "Niagara Falls, NY",
    "Williamsville, NY",
    "Tonawanda, NY",
    "Lockport, NY",
    "West Seneca, NY",
    "Lancaster, NY",
    "Kenmore, NY",
]

# Define mappings between industries and interests
industry_interest_mappings = {
    "Technology": ["Software Development", "Data Science", "Product Management", "Data Analytics"],
    "Marketing": ["Digital Marketing", "Market Research", "Advertising", "Public Relations"],
    "Art & Design": ["Graphic Design", "Illustration", "Web Design", "Photography"],
    "Finance": ["Financial Analysis", "Investment Banking", "Accounting", "Financial Planning"],
}

# Define universities for matching locations
universities = {
    "Buffalo, NY": ["University at Buffalo", "Canisius College", "Buffalo State College"],
    "Amherst, NY": ["Daemen College"],
    "Niagara Falls, NY": ["Niagara University"],
    "Williamsville, NY": ["Medaille College"],
    "Cheektowaga, NY": ["University of Cheektowaga"],
    "Niagara Falls, NY": ["University of Niagra Falls"],
    "Williamsville, NY": ["University of Williamsville"],
    "Tonawanda, NY": ["University of Tonawanda"],
    "Lockport, NY": ["University of Lockport"],
    "West Seneca, NY": ["University of Seneca"],
    "Lancaster, NY": ["University of Lancaster"],
    "Kenmore, NY": ["University of Kenmore"],
}

# Define skill tags based on interests
skill_tags = {
    "Technology": ["Python", "Java", "Web Development", "Machine Learning"],
    "Marketing": ["Digital Marketing", "Social Media Advertising", "SEO", "Marketing Strategy"],
    "Art & Design": ["Graphic Design", "Illustration", "UI/UX Design", "Photography"],
    "Finance": ["Financial Analysis", "Investment Strategies", "Accounting Principles", "Financial Modeling"],
}

# Create an empty list to store generated data
data = []

# Generate 500 rows of data
for user_id in range(1, 501):
    is_mentor_candidate = random.choice([True, False])
    if is_mentor_candidate:
        startup_experience = random.randint(4, 5)
        age = int(np.random.normal(mentor_mean_age, mentor_std_dev))
        age = min(max_age, max(min_age, age))
    else:
        age = random.randint(min_age, max_age)
        startup_experience = random.randint(0, 5)
    gender = random.choice(["Male", "Female", "Non-binary"])
    location = random.choice(locations)
    industry = random.choice(list(industry_interest_mappings.keys()))
    interests = random.choice(industry_interest_mappings[industry])
    mentor = "Yes" if is_mentor_candidate else "No"
    university = random.choice(universities.get(location, []))  # Match location to universities
    availability_hours = random.randint(1, 3)  # Hours per week

    if interests:
        available_skills = skill_tags.get(interests, [])
        max_skills_to_sample = min(len(available_skills), random.randint(1, 3))
        skills = random.sample(available_skills, k=max_skills_to_sample)
    else:
        skills = []

    data.append([user_id, age, gender, location, industry, interests, startup_experience, mentor, university, availability_hours, skills])

df = pd.DataFrame(data, columns=["user_id", "age", "gender", "location", "industry", "interests", "startup_experience", "mentor", "university", "availability_hours", "skills"])

df.to_csv("users.csv", index=False)

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def apply_encodings(value, encoding_dict):
    return int(encoding_dict[value])

def myencode(data):
    encodings = dict()
    for col in data.columns:
        unique_vals = list(set(data[col].values))
        encoding_dict = {unique_val: i for i, unique_val in enumerate(unique_vals)}
        encodings[col] = encoding_dict
    for col, encoding_dict in encodings.items():
      data[col] = data[col].apply(lambda x: apply_encodings(x, encoding_dict))
    return data, encodings

data = pd.read_csv("users.csv")

numerical_attributes = ["startup_experience", "availability_hours"]
categorical_attributes = ["gender", "location", "industry", "university"]

attribute_weights = {
    "location": 3.0,
    "startup_experience": 2.0,
    "industry": 2.0,
    "university": 1.0,
    "gender": 1.0,
    "age": 1.0,
    "availability_hours": 2.0,
}
encoded_categorical_features, encodings = myencode(data[categorical_attributes])
mentors = data[data["mentor"] == "Yes"]
mentees = data[data["mentor"] == "No"]
mentor_features_numerical = mentors[numerical_attributes].values * np.array([attribute_weights[attr] for attr in numerical_attributes])
mentee_features_numerical = mentees[numerical_attributes].values * np.array([attribute_weights[attr] for attr in numerical_attributes])

mentor_features_categorical = encoded_categorical_features.iloc[mentors.index].astype(float).values
mentor_features_categorical *= np.array([attribute_weights[attr] for attr in categorical_attributes])
mentee_features_categorical = encoded_categorical_features.iloc[mentees.index].astype(float).values
mentee_features_categorical *= np.array([attribute_weights[attr] for attr in categorical_attributes])

mentor_features = np.hstack((mentor_features_numerical, mentor_features_categorical))
mentee_features = np.hstack((mentee_features_numerical, mentee_features_categorical))

similarity_matrix = cosine_similarity(mentee_features, mentor_features)

print(similarity_matrix)
# Out:
# [[0.55641657 0.54010803 0.61250537 ... 0.66178974 0.57196944 0.76244017]
#  [0.77177168 0.89845282 0.78214295 ... 0.82714429 0.76870611 0.11986224]
#  [0.81572594 0.71630472 0.80974924 ... 0.76145539 0.81158    0.83112671]
#  ...
#  [0.73900834 0.71439601 0.77584088 ... 0.66485468 0.57250116 0.70298972]
#  [0.96188283 0.96720883 0.96721858 ... 0.9603306  0.96360922 0.51402323]
#  [0.82618439 0.92599269 0.82403645 ... 0.81795853 0.77631944 0.16777798]]
# <ipython-input-38-15fb33119d04>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].apply(lambda x: apply_encodings(x, encoding_dict))

# %%
# inference
num_recommendations = 5
recommendations = {}

for i, mentee_index in enumerate(mentees.index):
    top_mentor_indices = similarity_matrix[i].argsort()[::-1][:num_recommendations]
    recommended_mentors = mentors.iloc[top_mentor_indices].index.tolist()
    recommendations[mentee_index] = recommended_mentors

for mentee_index, recommended_mentors in recommendations.items():
    mentee_name = data.loc[mentee_index, "user_id"]
    mentor_names = [data.loc[mentor_index, "user_id"] for mentor_index in recommended_mentors]
    print(f"Mentee {mentee_name} should consider mentors: {mentor_names}")
# Out:
# Mentee 5 should consider mentors: [330, 401, 225, 57, 324]
# Mentee 7 should consider mentors: [450, 406, 446, 219, 60]
# Mentee 8 should consider mentors: [476, 126, 32, 311, 98]
# Mentee 10 should consider mentors: [397, 9, 154, 410, 298]
# Mentee 12 should consider mentors: [69, 386, 59, 119, 248]
# Mentee 13 should consider mentors: [456, 358, 54, 277, 63]
# Mentee 14 should consider mentors: [54, 210, 456, 213, 201]
# Mentee 16 should consider mentors: [54, 201, 213, 456, 163]
# Mentee 19 should consider mentors: [458, 417, 231, 230, 222]
# Mentee 20 should consider mentors: [350, 481, 408, 244, 418]
# Mentee 22 should consider mentors: [450, 136, 326, 339, 331]
# Mentee 23 should consider mentors: [387, 163, 216, 206, 146]
# Mentee 24 should consider mentors: [330, 419, 324, 164, 486]
# Mentee 25 should consider mentors: [57, 86, 238, 172, 401]
# Mentee 26 should consider mentors: [319, 384, 303, 96, 32]
# Mentee 28 should consider mentors: [82, 189, 149, 410, 154]
# Mentee 29 should consider mentors: [418, 339, 331, 450, 388]
# Mentee 34 should consider mentors: [62, 33, 194, 482, 424]
# Mentee 35 should consider mentors: [456, 201, 213, 54, 277]
# Mentee 36 should consider mentors: [210, 54, 358, 213, 201]
# Mentee 37 should consider mentors: [450, 219, 406, 446, 60]
# Mentee 44 should consider mentors: [50, 183, 265, 461, 217]
# Mentee 47 should consider mentors: [456, 54, 201, 213, 277]
# Mentee 49 should consider mentors: [164, 419, 486, 324, 330]
# Mentee 53 should consider mentors: [271, 309, 319, 250, 221]
# Mentee 56 should consider mentors: [484, 458, 64, 313, 439]
# Mentee 58 should consider mentors: [201, 213, 456, 163, 387]
# Mentee 61 should consider mentors: [484, 313, 64, 439, 431]
# Mentee 65 should consider mentors: [281, 168, 43, 189, 82]
# Mentee 67 should consider mentors: [213, 201, 456, 163, 387]
# Mentee 68 should consider mentors: [213, 201, 456, 163, 387]
# Mentee 70 should consider mentors: [63, 111, 277, 358, 54]
# Mentee 72 should consider mentors: [450, 136, 326, 406, 447]
# Mentee 73 should consider mentors: [201, 213, 456, 163, 387]
# Mentee 74 should consider mentors: [401, 225, 57, 86, 360]
# Mentee 75 should consider mentors: [52, 57, 96, 238, 172]
# Mentee 77 should consider mentors: [401, 456, 198, 188, 365]
# Mentee 78 should consider mentors: [458, 484, 64, 231, 230]
# Mentee 81 should consider mentors: [2, 203, 461, 265, 474]
# Mentee 83 should consider mentors: [57, 86, 172, 238, 401]
# Mentee 87 should consider mentors: [51, 48, 326, 40, 136]
# Mentee 88 should consider mentors: [484, 313, 64, 439, 165]
# Mentee 89 should consider mentors: [418, 350, 447, 38, 339]
# Mentee 91 should consider mentors: [51, 223, 108, 71, 50]
# Mentee 92 should consider mentors: [331, 339, 326, 38, 378]
# Mentee 93 should consider mentors: [481, 408, 388, 128, 424]
# Mentee 97 should consider mentors: [313, 165, 439, 158, 322]
# Mentee 99 should consider mentors: [456, 54, 201, 213, 302]
# Mentee 100 should consider mentors: [213, 201, 456, 206, 387]
# Mentee 101 should consider mentors: [206, 441, 162, 146, 286]
# Mentee 102 should consider mentors: [331, 339, 326, 38, 378]
# Mentee 103 should consider mentors: [80, 3, 387, 163, 286]
# Mentee 104 should consider mentors: [450, 406, 446, 219, 60]
# Mentee 105 should consider mentors: [213, 201, 456, 387, 163]
# Mentee 106 should consider mentors: [60, 219, 446, 406, 273]
# Mentee 109 should consider mentors: [326, 136, 450, 378, 66]
# Mentee 110 should consider mentors: [286, 146, 80, 1, 3]
# Mentee 113 should consider mentors: [277, 111, 456, 201, 213]
# Mentee 114 should consider mentors: [244, 446, 443, 147, 258]
# Mentee 116 should consider mentors: [456, 401, 201, 213, 57]
# Mentee 117 should consider mentors: [484, 64, 458, 439, 21]
# Mentee 118 should consider mentors: [95, 278, 147, 38, 66]
# Mentee 120 should consider mentors: [387, 163, 201, 213, 210]
# Mentee 121 should consider mentors: [225, 159, 401, 348, 360]
# Mentee 122 should consider mentors: [450, 326, 136, 339, 331]
# Mentee 123 should consider mentors: [302, 273, 183, 50, 217]
# Mentee 124 should consider mentors: [225, 159, 126, 348, 360]
# Mentee 125 should consider mentors: [458, 64, 484, 439, 230]
# Mentee 127 should consider mentors: [192, 259, 220, 194, 40]
# Mentee 129 should consider mentors: [42, 261, 141, 372, 197]
# Mentee 130 should consider mentors: [331, 339, 418, 450, 38]
# Mentee 131 should consider mentors: [192, 259, 220, 194, 40]
# Mentee 132 should consider mentors: [302, 273, 183, 210, 50]
# Mentee 133 should consider mentors: [458, 484, 64, 231, 230]
# Mentee 138 should consider mentors: [214, 137, 185, 216, 162]
# Mentee 139 should consider mentors: [271, 309, 221, 310, 455]
# Mentee 140 should consider mentors: [201, 213, 54, 456, 210]
# Mentee 142 should consider mentors: [273, 406, 450, 219, 302]
# Mentee 143 should consider mentors: [450, 339, 136, 418, 331]
# Mentee 144 should consider mentors: [408, 481, 388, 446, 327]
# Mentee 145 should consider mentors: [450, 406, 136, 219, 326]
# Mentee 148 should consider mentors: [302, 183, 50, 273, 217]
# Mentee 150 should consider mentors: [50, 265, 183, 302, 217]
# Mentee 151 should consider mentors: [163, 387, 80, 286, 146]
# Mentee 152 should consider mentors: [213, 201, 277, 54, 456]
# Mentee 153 should consider mentors: [446, 265, 204, 217, 50]
# Mentee 155 should consider mentors: [147, 244, 446, 60, 327]
# Mentee 156 should consider mentors: [111, 214, 79, 453, 403]
# Mentee 157 should consider mentors: [446, 244, 60, 147, 327]
# Mentee 166 should consider mentors: [225, 159, 401, 348, 360]
# Mentee 167 should consider mentors: [441, 80, 3, 286, 146]
# Mentee 169 should consider mentors: [456, 213, 201, 387, 163]
# Mentee 170 should consider mentors: [387, 163, 3, 216, 214]
# Mentee 171 should consider mentors: [54, 456, 213, 201, 63]
# Mentee 173 should consider mentors: [195, 479, 358, 210, 54]
# Mentee 175 should consider mentors: [206, 55, 27, 111, 274]
# Mentee 176 should consider mentors: [210, 79, 453, 387, 163]
# Mentee 177 should consider mentors: [165, 11, 463, 417, 313]
# Mentee 178 should consider mentors: [339, 331, 38, 418, 136]
# Mentee 181 should consider mentors: [322, 158, 500, 94, 255]
# Mentee 182 should consider mentors: [369, 342, 455, 250, 486]
# Mentee 184 should consider mentors: [408, 481, 388, 446, 327]
# Mentee 186 should consider mentors: [456, 277, 213, 201, 54]
# Mentee 187 should consider mentors: [165, 313, 322, 158, 463]
# Mentee 190 should consider mentors: [230, 417, 231, 222, 458]
# Mentee 191 should consider mentors: [52, 86, 57, 172, 238]
# Mentee 193 should consider mentors: [86, 57, 225, 401, 404]
# Mentee 196 should consider mentors: [401, 330, 57, 225, 86]
# Mentee 200 should consider mentors: [277, 111, 274, 262, 185]
# Mentee 202 should consider mentors: [273, 302, 251, 71, 183]
# Mentee 205 should consider mentors: [50, 265, 183, 302, 217]
# Mentee 207 should consider mentors: [273, 302, 251, 71, 108]
# Mentee 208 should consider mentors: [456, 54, 277, 201, 213]
# Mentee 209 should consider mentors: [472, 403, 55, 27, 111]
# Mentee 211 should consider mentors: [210, 183, 302, 273, 387]
# Mentee 215 should consider mentors: [210, 213, 201, 216, 185]
# Mentee 218 should consider mentors: [418, 339, 447, 38, 450]
# Mentee 226 should consider mentors: [431, 231, 21, 230, 484]
# Mentee 227 should consider mentors: [230, 231, 458, 222, 417]
# Mentee 228 should consider mentors: [500, 94, 255, 423, 439]
# Mentee 229 should consider mentors: [158, 322, 425, 423, 94]
# Mentee 233 should consider mentors: [275, 112, 441, 31, 80]
# Mentee 234 should consider mentors: [165, 463, 354, 222, 11]
# Mentee 235 should consider mentors: [80, 3, 441, 387, 163]
# Mentee 237 should consider mentors: [450, 219, 406, 326, 136]
# Mentee 240 should consider mentors: [450, 446, 406, 219, 447]
# Mentee 241 should consider mentors: [3, 80, 286, 146, 163]
# Mentee 242 should consider mentors: [423, 425, 255, 94, 276]
# Mentee 243 should consider mentors: [387, 163, 80, 213, 201]
# Mentee 245 should consider mentors: [387, 163, 3, 216, 214]
# Mentee 246 should consider mentors: [450, 136, 326, 339, 447]
# Mentee 247 should consider mentors: [439, 423, 64, 255, 94]
# Mentee 249 should consider mentors: [163, 387, 201, 213, 206]
# Mentee 252 should consider mentors: [456, 201, 213, 277, 54]
# Mentee 253 should consider mentors: [232, 17, 294, 84, 204]
# Mentee 254 should consider mentors: [387, 163, 265, 213, 201]
# Mentee 256 should consider mentors: [219, 378, 66, 95, 278]
# Mentee 257 should consider mentors: [327, 446, 204, 17, 408]
# Mentee 260 should consider mentors: [219, 6, 450, 406, 371]
# Mentee 263 should consider mentors: [313, 165, 439, 158, 322]
# Mentee 269 should consider mentors: [222, 354, 463, 458, 165]
# Mentee 270 should consider mentors: [64, 439, 484, 458, 313]
# Mentee 272 should consider mentors: [210, 163, 387, 284, 217]
# Mentee 279 should consider mentors: [204, 60, 17, 446, 41]
# Mentee 280 should consider mentors: [277, 456, 201, 213, 63]
# Mentee 282 should consider mentors: [201, 213, 456, 387, 163]
# Mentee 283 should consider mentors: [273, 183, 284, 302, 217]
# Mentee 285 should consider mentors: [468, 374, 39, 372, 57]
# Mentee 287 should consider mentors: [57, 172, 238, 86, 96]
# Mentee 288 should consider mentors: [486, 164, 324, 419, 362]
# Mentee 289 should consider mentors: [15, 362, 4, 324, 486]
# Mentee 290 should consider mentors: [265, 2, 461, 50, 203]
# Mentee 291 should consider mentors: [9, 410, 427, 189, 82]
# Mentee 292 should consider mentors: [493, 90, 45, 328, 480]
# Mentee 295 should consider mentors: [50, 302, 183, 265, 51]
# Mentee 296 should consider mentors: [456, 201, 213, 54, 277]
# Mentee 297 should consider mentors: [11, 343, 321, 463, 165]
# Mentee 299 should consider mentors: [441, 135, 274, 112, 262]
# Mentee 300 should consider mentors: [450, 339, 136, 418, 331]
# Mentee 304 should consider mentors: [76, 496, 149, 415, 440]
# Mentee 305 should consider mentors: [48, 51, 71, 223, 108]
# Mentee 306 should consider mentors: [164, 486, 342, 369, 419]
# Mentee 307 should consider mentors: [204, 446, 60, 327, 217]
# Mentee 312 should consider mentors: [183, 50, 302, 217, 265]
# Mentee 315 should consider mentors: [446, 388, 265, 327, 50]
# Mentee 316 should consider mentors: [214, 185, 111, 216, 79]
# Mentee 317 should consider mentors: [401, 225, 330, 159, 360]
# Mentee 318 should consider mentors: [302, 50, 273, 183, 48]
# Mentee 323 should consider mentors: [165, 313, 458, 484, 64]
# Mentee 325 should consider mentors: [456, 201, 213, 277, 54]
# Mentee 329 should consider mentors: [210, 54, 201, 213, 273]
# Mentee 332 should consider mentors: [330, 324, 225, 401, 419]
# Mentee 333 should consider mentors: [63, 358, 111, 195, 479]
# Mentee 334 should consider mentors: [500, 94, 255, 423, 322]
# Mentee 335 should consider mentors: [258, 408, 481, 482, 424]
# Mentee 336 should consider mentors: [439, 423, 64, 255, 94]
# Mentee 337 should consider mentors: [360, 348, 159, 188, 365]
# Mentee 338 should consider mentors: [165, 313, 11, 463, 340]
# Mentee 341 should consider mentors: [30, 480, 45, 328, 46]
# Mentee 344 should consider mentors: [450, 219, 326, 406, 136]
# Mentee 346 should consider mentors: [225, 57, 86, 52, 311]
# Mentee 347 should consider mentors: [112, 441, 80, 85, 161]
# Mentee 351 should consider mentors: [18, 134, 406, 219, 443]
# Mentee 353 should consider mentors: [231, 230, 458, 222, 417]
# Mentee 355 should consider mentors: [398, 238, 172, 112, 85]
# Mentee 357 should consider mentors: [206, 387, 163, 80, 201]
# Mentee 359 should consider mentors: [217, 265, 203, 284, 183]
# Mentee 364 should consider mentors: [456, 54, 201, 213, 163]
# Mentee 366 should consider mentors: [15, 362, 4, 324, 486]
# Mentee 367 should consider mentors: [225, 401, 198, 365, 188]
# Mentee 368 should consider mentors: [427, 397, 9, 154, 149]
# Mentee 370 should consider mentors: [322, 158, 165, 321, 313]
# Mentee 373 should consider mentors: [64, 484, 458, 439, 21]
# Mentee 375 should consider mentors: [54, 358, 63, 195, 479]
# Mentee 376 should consider mentors: [217, 284, 183, 265, 50]
# Mentee 377 should consider mentors: [358, 456, 54, 277, 479]
# Mentee 379 should consider mentors: [158, 322, 423, 94, 255]
# Mentee 380 should consider mentors: [48, 461, 71, 51, 108]
# Mentee 381 should consider mentors: [251, 273, 71, 108, 223]
# Mentee 382 should consider mentors: [456, 277, 201, 213, 54]
# Mentee 383 should consider mentors: [158, 423, 322, 94, 255]
# Mentee 389 should consider mentors: [456, 54, 201, 213, 163]
# Mentee 390 should consider mentors: [484, 64, 439, 423, 94]
# Mentee 391 should consider mentors: [418, 450, 339, 331, 50]
# Mentee 392 should consider mentors: [342, 369, 59, 221, 310]
# Mentee 393 should consider mentors: [450, 339, 136, 418, 326]
# Mentee 394 should consider mentors: [330, 401, 225, 57, 324]
# Mentee 395 should consider mentors: [324, 330, 164, 419, 362]
# Mentee 396 should consider mentors: [204, 60, 446, 17, 41]
# Mentee 399 should consider mentors: [201, 213, 163, 387, 456]
# Mentee 400 should consider mentors: [206, 387, 163, 80, 201]
# Mentee 402 should consider mentors: [219, 406, 450, 273, 302]
# Mentee 405 should consider mentors: [126, 225, 261, 476, 365]
# Mentee 407 should consider mentors: [210, 54, 456, 358, 213]
# Mentee 409 should consider mentors: [423, 255, 94, 500, 158]
# Mentee 411 should consider mentors: [385, 266, 363, 308, 386]
# Mentee 412 should consider mentors: [46, 30, 480, 328, 45]
# Mentee 413 should consider mentors: [95, 278, 147, 38, 66]
# Mentee 414 should consider mentors: [220, 259, 251, 192, 71]
# Mentee 416 should consider mentors: [387, 163, 206, 162, 201]
# Mentee 420 should consider mentors: [201, 213, 387, 163, 206]
# Mentee 421 should consider mentors: [183, 284, 273, 217, 474]
# Mentee 422 should consider mentors: [248, 119, 59, 310, 349]
# Mentee 426 should consider mentors: [50, 265, 183, 302, 217]
# Mentee 428 should consider mentors: [327, 204, 41, 17, 294]
# Mentee 429 should consider mentors: [50, 265, 183, 302, 446]
# Mentee 430 should consider mentors: [387, 163, 206, 162, 201]
# Mentee 432 should consider mentors: [472, 403, 160, 264, 141]
# Mentee 433 should consider mentors: [251, 273, 71, 108, 223]
# Mentee 434 should consider mentors: [401, 456, 86, 57, 225]
# Mentee 435 should consider mentors: [168, 485, 199, 43, 298]
# Mentee 436 should consider mentors: [262, 274, 264, 320, 275]
# Mentee 437 should consider mentors: [350, 95, 278, 244, 388]
# Mentee 438 should consider mentors: [384, 303, 352, 492, 266]
# Mentee 442 should consider mentors: [203, 2, 115, 293, 474]
# Mentee 444 should consider mentors: [388, 481, 408, 327, 446]
# Mentee 445 should consider mentors: [50, 302, 265, 183, 273]
# Mentee 448 should consider mentors: [197, 141, 42, 261, 403]
# Mentee 449 should consider mentors: [418, 450, 339, 447, 331]
# Mentee 452 should consider mentors: [273, 302, 183, 251, 284]
# Mentee 454 should consider mentors: [456, 277, 213, 201, 54]
# Mentee 457 should consider mentors: [450, 219, 406, 60, 326]
# Mentee 459 should consider mentors: [277, 185, 213, 201, 216]
# Mentee 460 should consider mentors: [418, 450, 339, 447, 331]
# Mentee 462 should consider mentors: [458, 484, 165, 64, 313]
# Mentee 464 should consider mentors: [450, 219, 406, 60, 273]
# Mentee 465 should consider mentors: [126, 32, 98, 451, 225]
# Mentee 466 should consider mentors: [198, 365, 188, 372, 360]
# Mentee 467 should consider mentors: [163, 387, 201, 213, 206]
# Mentee 469 should consider mentors: [277, 456, 401, 213, 201]
# Mentee 470 should consider mentors: [350, 95, 278, 244, 388]
# Mentee 471 should consider mentors: [172, 238, 86, 57, 85]
# Mentee 473 should consider mentors: [265, 163, 387, 50, 201]
# Mentee 475 should consider mentors: [192, 220, 259, 281, 40]
# Mentee 477 should consider mentors: [500, 94, 255, 439, 313]
# Mentee 478 should consider mentors: [350, 95, 278, 244, 388]
# Mentee 483 should consider mentors: [201, 213, 302, 163, 387]
# Mentee 487 should consider mentors: [57, 86, 238, 172, 401]
# Mentee 488 should consider mentors: [387, 163, 265, 50, 213]
# Mentee 489 should consider mentors: [484, 64, 458, 431, 439]
# Mentee 491 should consider mentors: [96, 238, 172, 119, 248]
# Mentee 494 should consider mentors: [372, 360, 348, 404, 188]
# Mentee 495 should consider mentors: [210, 54, 358, 479, 195]
# Mentee 497 should consider mentors: [456, 213, 201, 277, 401]
# Mentee 498 should consider mentors: [33, 62, 194, 441, 80]
# Mentee 499 should consider mentors: [50, 183, 302, 265, 446]
